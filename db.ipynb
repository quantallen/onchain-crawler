# %%
import pandas as pd
import sqlalchemy
from datetime import datetime, timedelta

conn = sqlalchemy.create_engine(f'postgresql://datateam:nbolh2n3mfHm@btse-prod-database-datateam-apn1.ccacmtkpnljd.ap-northeast-1.rds.amazonaws.com:5432/datateam')

# Query table
df_test = pd.read_sql(
"""
SELECT
 *
FROM
    crypto_news_coins
""",
conn
)

# %%
df_test
# Out:
#         id ticker                       blog_link goverance_forum_link  \
# 0        1    BTC
# 1        2    ETH
# 2        3   BUSD        https://medium.com/paxos
# 3        4   USDC  https://medium.com/centre-blog
# 4        5    ETC
# ...    ...    ...                             ...                  ...
# 1237  1238   UNCL
# 1238  1239  WAMPL
# 1239  1240    CAT
# 1240  1241  MINER
# 1241  1242    ATS
#
#                      created_at
# 0    2022-09-23 07:06:05.148163
# 1    2022-09-23 07:06:05.148163
# 2    2022-09-23 07:06:05.148163
# 3    2022-09-23 07:06:05.148163
# 4    2022-09-23 07:06:05.148163
# ...                         ...
# 1237 2022-09-23 07:06:05.148163
# 1238 2022-09-23 07:06:05.148163
# 1239 2022-09-23 07:06:05.148163
# 1240 2022-09-23 07:06:05.148163
# 1241 2022-09-23 07:06:05.148163
#
# [1242 rows x 5 columns]

# %%
df_post = pd.read_sql(
"""
SELECT
 *
FROM
    crypto_news_goverance_posts
""",
conn
)
df_post
# Out:
#     id                                               link  \
# 0    1  https://discuss.ens.domains/t/please-use-dao-f...
# 1    2  https://discuss.ens.domains/t/planetable-xyz-n...
# 2    3  https://discuss.ens.domains/t/limit-short-doma...
# 3    4  https://discuss.ens.domains/t/term-2-grants-su...
# 4    5  https://discuss.ens.domains/t/predomain-open-s...
# 5    6  https://discuss.ens.domains/t/ens-name-lookup-...
# 6    7  https://discuss.ens.domains/t/public-goods-tra...
# 7    8  https://forum.apecoin.com/t/apeclub-token-gate...
# 8    9  https://discuss.ens.domains/t/planetable-xyz-n...
# 9   10  https://discourse.bitdao.io/t/heloo-nice-proje...
# 10  11  https://radicle.community/t/dao-tooling-workst...
# 11  12  https://governance.aave.com/t/updated-proposal...
# 12  13  https://forum.api3.org/t/security-announcement...
# 13  14  https://discuss.ens.domains/t/ens-controller-v...
# 14  15  https://discuss.ens.domains/t/ep13-executable-...
# ...

# %%
df_post = pd.read_sql(
"""
SELECT
 *
FROM
    crypto_news_blog_posts
""",
conn
)
df_post
# Out:
#     id                                               link  \
# 0    1  https://medium.com/nearprotocol/blogchain-open...
# 1    2  https://medium.com/nearprotocol/blogchain-open...
# 2    3  https://medium.com/sora-xor/xst-a-platform-for...
# 3    4  https://medium.com/pancakeswap/%E9%9A%86%E9%87...
# 4    5  https://blog.thundercore.com/technical-update-...
# 5    6  https://medium.com/chiliz/meet-us-at-token2049...
# 6    7  https://medium.com/klaytn/the-klaytn-governanc...
# 7    8  https://medium.com/stackos/summary-of-the-stac...
# 8    9  https://medium.com/bolt-global/bolt-joins-sing...
# 9   10  https://medium.com/dfinity/considerations-for-...
# 10  11  https://medium.com/render-token/behind-the-net...
# 11  12  https://medium.com/theecosystem/sparklearn-edt...
# 12  13  https://medium.com/pancakeswap/presentamos-sta...
# 13  14  https://medium.com/pancakeswap/reinventing-rec...
# 14  15  https://medium.com/functionx/summary-of-functi...
# ...

# %%
connection = conn.connect()

sql = "SELECT \
  crypto_news_coins.ticker AS ticker, \
  crypto_news_goverance_posts.link AS link \
  FROM crypto_news_coins \
  INNER JOIN crypto_news_goverance_posts ON crypto_news_coins.id = crypto_news_goverance_posts.coin_id"

myresult = connection.execute(sql)


for x in myresult:
  print(x)
# Out:
# ('ENS', 'https://discuss.ens.domains/t/please-use-dao-funds-and-ens-dao-twitter-account-to-create-and-promote-educational-content/14495')
# ('ENS', 'https://discuss.ens.domains/t/planetable-xyz-native-macos-app-for-building-dwebsites-on-ipfs-ens/14490')
# ('ENS', 'https://discuss.ens.domains/t/limit-short-domain-overcharge-to-alphanumeric-characters-to-avoid-linguistic-discrimination/14523')
# ('ENS', 'https://discuss.ens.domains/t/term-2-grants-summary/14115')
# ('ENS', 'https://discuss.ens.domains/t/predomain-open-source-decentralised-ens-search-registration-and-marketplace/14074')
# ('ENS', 'https://discuss.ens.domains/t/ens-name-lookup-telegram-bot/14533')
# ('ENS', 'https://discuss.ens.domains/t/public-goods-translation-of-ens-into-russian/12564')
# ('APE', 'https://forum.apecoin.com/t/apeclub-token-gated-social-network-for-the-yuga-community/8511')
# ('ENS', 'https://discuss.ens.domains/t/planetable-xyz-native-macos-app-for-building-dwebsites-on-ipfs-ens/14490')
# ...
