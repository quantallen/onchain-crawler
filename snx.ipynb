# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By

driver = webdriver.Chrome(ChromeDriverManager().install())
driver.implicitly_wait(6)

driver.get('https://sips.synthetix.io/all-sip/')
find_href = driver.find_elements(By.CLASS_NAME, "sipnum")
print(find_href)
#find_date = driver.find_elements(By.CLASS_NAME, "post-activity")
list_of_url = []
list_of_date = []
for link in find_href:
    #a = link.find_element(By.TAG_NAME, 'a').get_attribute('href')
    a = link.get_attribute('href')
    list_of_url.append(a)
driver.quit()
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 103.0.5060
# [WDM] - Get LATEST chromedriver version for 103.0.5060 google-chrome
# [WDM] - Driver [/Users/allen.kuo/.wdm/drivers/chromedriver/mac64/103.0.5060.134/chromedriver] found in cache
# /var/folders/nz/kdjg06xx7m92snslrqtd87v8qy9p5w/T/ipykernel_31841/2247166091.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
# ...

# %%
list_of_url
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
# ...

# %%
from bs4 import BeautifulSoup
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/allen.kuo/crawler_onchain/snx.ipynb Cell 3' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/allen.kuo/crawler_onchain/snx.ipynb#ch0000004?line=0'>1</a> from bs4 import BeautifulSoup
#
# ModuleNotFoundError: No module named 'bs4'

# %%
pip install beautifulsoup4
# Out:
# ...
#   Using cached beautifulsoup4-4.11.1-py3-none-any.whl (128 kB)
# ...
#   Using cached soupsieve-2.3.2.post1-py3-none-any.whl (37 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By

driver = webdriver.Chrome(ChromeDriverManager().install())
driver.implicitly_wait(6)

driver.get('https://agora.terra.money/')
find_href = driver.find_elements(By.CLASS_NAME, "DiscussionRow")
print(find_href)
#find_date = driver.find_elements(By.CLASS_NAME, "post-activity")
list_of_url = []
list_of_date = []
for link in find_href:
    #a = link.find_element(By.TAG_NAME, 'a').get_attribute('href')
    a = link.get_attribute('href')
    list_of_url.append(a)
driver.quit()
# Out:
# /tmp/ipykernel_1726575/1436516378.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# /home/allen.kuo/crawler_onchain/snx.ipynb Cell 5 in <cell line: 5>()
#       <a href='vscode-notebook-cell://ssh-remote%2Bfrozen2/home/allen.kuo/crawler_onchain/snx.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> from webdriver_manager.chrome import ChromeDriverManager
#       <a href='vscode-notebook-cell://ssh-remote%2Bfrozen2/home/allen.kuo/crawler_onchain/snx.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> from selenium.webdriver.common.by import By
# ...
